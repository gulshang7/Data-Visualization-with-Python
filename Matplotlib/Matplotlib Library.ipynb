# %% [markdown]
# # MATPLOTLIB
#                                                                                                           By Gulshan Gedam

# %% [markdown]
# ## Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import randint, randn

# %%
# %matplotlib inline

# %%
x = np.linspace(1,10,20)
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y = randint(1,50,20)
y
# Out:
# array([ 7, 19, 16, 35, 38, 41, 46, 38, 34, 22,  5, 34, 15, 41, 14, 37, 23,
#        16, 17, 49])

# %%
x.size, y.size
# Out:
# (20, 20)

# %%
help(plt)
# Out:
# Help on module matplotlib.pyplot in matplotlib:
#
# NAME
#     matplotlib.pyplot
#
# DESCRIPTION
#     `matplotlib.pyplot` is a state-based interface to matplotlib. It provides
#     an implicit,  MATLAB-like, way of plotting.  It also opens figures on your
#     screen, and acts as the figure GUI manager.
#
#     pyplot is mainly intended for interactive plots and simple cases of
#     programmatic plot generation::
#
#         import numpy as np
#         import matplotlib.pyplot as plt
#
#         x = np.arange(0, 5, 0.1)
#         y = np.sin(x)
#         plt.plot(x, y)
#
#     The explicit (object-oriented) API is recommended for complex plots, though
#     pyplot is still usually used to create the figure and often the axes in the
#     figure. See `.pyplot.figure`, `.pyplot.subplots`, and
#     `.pyplot.subplot_mosaic` to create figures, and
#     :doc:`Axes API <../axes_api>` for the plotting methods on an axes::
#
#         import numpy as np
# ...

# %%
plt.plot(y)

# %%
 y = y.cumsum()

# %%
plt.plot(y)

# %%
x1 = x.cumsum()

# %%
plt.plot(x1,y)

# %%
plt.plot(x,y)

# %%
plt.plot(x,y, color = 'r')

# %%
plt.plot(x,y, color = 'r', marker = 'o')

# %%
plt.plot(x,y, color = 'r', marker = 'o', linestyle = '--')

# %% [markdown]
# ## Label

# %%
plt.plot(x,y, color = 'r', marker = 'o', linestyle = '--')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('This is a Demo Plot')
plt.show()

# %% [markdown]
# ## Scatter, Bar, Hist and Box Plot

# %%
x,y
# Out:
# (array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#          3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#          5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#          8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ]),
#  array([ 32,  80, 100, 120, 140, 156, 176, 211, 258, 297, 327, 343, 372,
#         374, 409, 450, 454, 468, 476, 514], dtype=int32))

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y, linewidths=5, color = 'r', alpha= 0.6)
plt.show()

# %%
b= [13,54,21,67,49]
a = ['a', 'b', 'c', 'd', 'e']

plt.bar(a,b)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(a,b, width = 0.6, color = 'g')
plt.show()

# %%
plt.hist(y)
# Out:
# (array([2., 2., 3., 1., 1., 1., 2., 3., 2., 3.]),
#  array([ 32. ,  80.2, 128.4, 176.6, 224.8, 273. , 321.2, 369.4, 417.6,
#         465.8, 514. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(y, rwidth=0.8, bins = 30, color = 'r')
# Out:
# (array([1., 0., 1., 0., 1., 1., 1., 1., 1., 0., 0., 1., 0., 0., 1., 0., 1.,
#         0., 1., 1., 0., 2., 0., 1., 0., 0., 2., 2., 0., 1.]),
#  array([ 32.        ,  48.06666667,  64.13333333,  80.2       ,
#          96.26666667, 112.33333333, 128.4       , 144.46666667,
#         160.53333333, 176.6       , 192.66666667, 208.73333333,
#         224.8       , 240.86666667, 256.93333333, 273.        ,
#         289.06666667, 305.13333333, 321.2       , 337.26666667,
#         353.33333333, 369.4       , 385.46666667, 401.53333333,
#         417.6       , 433.66666667, 449.73333333, 465.8       ,
#         481.86666667, 497.93333333, 514.        ]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ## Box Plot

# %%
data = [np.random.normal(0, std, 100) for std in range(1,3)]

# %%
data
# Out:
# [array([ 0.12041789, -1.27459238, -0.14691869, -0.82231464,  1.18968567,
#         -0.30127151,  0.37171372, -0.73902945,  0.32085813,  1.02789211,
#          0.84684454, -0.73255922,  0.59735865, -0.23085   , -0.73221726,
#         -0.386503  ,  1.08210702, -0.71324044, -1.34396722,  0.99155256,
#         -0.00874152, -1.38752207, -2.20095661, -0.58974341,  0.23305419,
#          1.5135181 , -2.44551923,  1.14529897, -1.63050534,  0.38966714,
#          0.51518939, -0.80840957, -0.14873965,  0.05908555,  0.53462886,
#         -0.1454477 , -0.60201054,  0.58476267, -0.18771254,  1.63436376,
#         -2.46392857, -1.95301558, -0.43908421,  0.21778506, -1.80142966,
#         -0.23808661,  0.98412331, -0.63821185, -1.03307211,  0.33921483,
#          0.58560739,  0.04314594, -2.47361327,  0.68926704,  0.40177388,
#         -0.41396072,  0.14865062, -1.2200374 , -1.17932704, -1.28697614,
#         -0.97506512, -0.5740845 ,  0.74285871,  1.19227337, -2.38613457,
# ...

# %%
data[0], data[1]
# Out:
# (array([ 0.12041789, -1.27459238, -0.14691869, -0.82231464,  1.18968567,
#         -0.30127151,  0.37171372, -0.73902945,  0.32085813,  1.02789211,
#          0.84684454, -0.73255922,  0.59735865, -0.23085   , -0.73221726,
#         -0.386503  ,  1.08210702, -0.71324044, -1.34396722,  0.99155256,
#         -0.00874152, -1.38752207, -2.20095661, -0.58974341,  0.23305419,
#          1.5135181 , -2.44551923,  1.14529897, -1.63050534,  0.38966714,
#          0.51518939, -0.80840957, -0.14873965,  0.05908555,  0.53462886,
#         -0.1454477 , -0.60201054,  0.58476267, -0.18771254,  1.63436376,
#         -2.46392857, -1.95301558, -0.43908421,  0.21778506, -1.80142966,
#         -0.23808661,  0.98412331, -0.63821185, -1.03307211,  0.33921483,
#          0.58560739,  0.04314594, -2.47361327,  0.68926704,  0.40177388,
#         -0.41396072,  0.14865062, -1.2200374 , -1.17932704, -1.28697614,
#         -0.97506512, -0.5740845 ,  0.74285871,  1.19227337, -2.38613457,
# ...

# %%
plt.boxplot(data, vert = True)
plt.show()

# %%
plt.boxplot(data, vert = True, patch_artist= True)
plt.show()

# %% [markdown]
# ## Subplot

# %%
x,y
# Out:
# (array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#          3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#          5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#          8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ]),
#  array([ 32,  80, 100, 120, 140, 156, 176, 211, 258, 297, 327, 343, 372,
#         374, 409, 450, 454, 468, 476, 514], dtype=int32))

# %%
y2 = x*y
y2
# Out:
# array([  32.        ,  117.89473684,  194.73684211,  290.52631579,
#         405.26315789,  525.47368421,  676.21052632,  910.63157895,
#        1235.68421053, 1563.15789474, 1875.94736842, 2130.21052632,
#        2486.52631579, 2677.05263158, 3121.31578947, 3647.36842105,
#        3894.84210526, 4236.63157895, 4534.52631579, 5140.        ])

# %%
plt.plot(y)
plt.plot(y2)

# %%
plt.plot(x,y)
plt.plot(x,y2)

# %%
plt.subplot(1,2,1) # 1 means 1 row and 2 means 2 columns and 1 means axis
plt.plot(x,y)

plt.subplot(1,2,2) # 1 means 1 row and 2 means 2 columns and 2 means axis
plt.plot(x,y2)

# %%
plt.subplot(1,2,1)
plt.plot(x,y, color = 'g', marker = 'o')

plt.subplot(1,2,2)
plt.plot(x,y2, color = 'r', marker = '*')

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.1, 0.65, 0.4, 0.3])

ax1.plot(x,y,'r')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_title('Y Plot')

ax2.plot(x,y2,'g')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('Y2 Plot')
# Out:
# Text(0.5, 1.0, 'Y2 Plot')

# %% [markdown]
# ### xlim, ylim, xticks and yticks

# %%
fig, ax = plt.subplots(1,2, figsize= (12,4))

ax[0].plot(x,y,x,y2)

ax[1].plot(x,y**2, 'k')

# %%
fig, ax = plt.subplots(1,2, figsize= (12,4))

ax[0].plot(x,y,x,y2)

ax[1].plot(x,y**2, 'k')
ax[1].set_ylim([0,10000])
# Out:
# (0.0, 10000.0)

# %%
fig, ax = plt.subplots(1,2, figsize= (12,4))

ax[0].plot(x,y,x,y2)

ax[1].plot(x,y**2, 'k')
ax[1].set_ylim([500,10000])
ax[1].set_xlim([-5,5])
# Out:
# (-5.0, 5.0)

# %%
fig, ax = plt.subplots(1,2, figsize= (12,4))

ax[0].plot(x,y,x,y2)
ax[0].set_xticks([1,4,9])

ax[1].plot(x,y**2, 'k')
ax[1].set_xticks([1,4,9])
ax[1].set_xticklabels([r'$\alpha$',r'$\beta$',r'$\delta$'])
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
labels = ['Frog', 'Cat', "Dog", 'Lion']
sizes = [15,30,45,80]

# %%
fig, ax = plt.subplots(figsize = (4,4))
ax.pie(sizes)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (4,4), dpi = 100)
ax.pie(sizes, labels = labels, autopct = '%1.1f%%', shadow = True, startangle = 90)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (4,4), dpi = 100)
explode = (0.1,0,0,0)
ax.pie(sizes, labels = labels, autopct = '%1.1f%%', shadow = True, startangle = 90, explode = explode)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (4,4), dpi = 100)
explode = (0.1,0.2,0.3,0.3)
ax.pie(sizes, labels = labels, autopct = '%1.1f%%', shadow = True, startangle = 90, explode = explode)
plt.show()

# %% [markdown]
# ### Pie Chart/Plot text coloring

# %%
fig, ax = plt.subplots(figsize = (4,4), dpi = 100)
explode = (0,0.1,0,0)
patches, texts, autotexts = ax.pie(sizes, labels = labels, autopct = '%1.1f%%', shadow = True, 
                                 startangle = 90, explode = explode)
plt.setp(autotexts, size = 13, color = 'black')
autotexts[1].set_color('white')
plt.show()

# %% [markdown]
# ## Nested Pie Chart

# %%
fig, ax = plt.subplots(dpi = 100)
size = 0.3

vals = np.array([[60, 32], [35,20], [26,36]])
vals_sum = vals.sum(axis =1)
vals_flat = vals.flatten()

cmap = plt.get_cmap('tab20c')
outer_color = cmap(np.arange(3)*8)
inner_color = cmap(np.arange(6)*12)

ax.pie(vals_sum,radius = 1, colors = outer_color, wedgeprops= dict(width = size, edgecolor = 'w'))
plt.show()

# %%
fig, ax = plt.subplots(dpi = 100)
size = 0.3

vals = np.array([[60, 32], [35,20], [26,36]])
vals_sum = vals.sum(axis =1)
vals_flat = vals.flatten()

cmap = plt.get_cmap('tab20c')
outer_color = cmap(np.arange(3)*4) #--> CHANGED
inner_color = cmap(np.arange(6)*3) #--> CHANGED

ax.pie(vals_sum,radius = 1, colors = outer_color, wedgeprops= dict(width = size, edgecolor = 'k')) #--> cHANGED
plt.show()

# %%
fig, ax = plt.subplots(dpi = 100)
size = 0.3

vals = np.array([[60, 32], [35,20], [26,36]])
vals_sum = vals.sum(axis =1)
vals_flat = vals.flatten()

cmap = plt.get_cmap('tab20c')
outer_color = cmap(np.arange(3)*4)
inner_color = cmap(np.arange(6)*5)

ax.pie(vals_sum,radius = 1, colors = outer_color, wedgeprops= dict(width = size, edgecolor = 'w'))
ax.pie(vals_flat,radius = 1-size, colors = inner_color, wedgeprops= dict(width = size, edgecolor = 'w'))

plt.show()

# %% [markdown]
# ## Labeling in Pie chart

# %%
fig, ax = plt.subplots (dpi = 100)
recipe = ["375 g Flour", "75 g Suger", "250 g Butter", "300 g Berries"]

data = [float(x.split(' ')[0]) for x in recipe]
ingredients = [x.split(' ')[-1] for x in recipe]

ax.pie(data)
plt.show()

# %%
fig, ax = plt.subplots (dpi = 100)
recipe = ["375 g Flour", "75 g Suger", "250 g Butter", "300 g Berries"]

data = [float(x.split(' ')[0]) for x in recipe]
ingredients = [x.split(' ')[-1] for x in recipe]

def func(pct, vals):
    absolute = int(pct/100. *np.sum(vals)) 
    return "{:.1f}% \n({:d} g)".format(pct, absolute)

ax.pie(data, autopct = lambda pct: func(pct, data), textprops = dict(color = 'w'))
plt.show()

# %%
fig, ax = plt.subplots (dpi = 100)
recipe = ["375 g Flour", "75 g Suger", "250 g Butter", "300 g Berries"]

data = [float(x.split(' ')[0]) for x in recipe]
ingredients = [x.split(' ')[-1] for x in recipe]

def func(pct, vals):
    absolute = int(pct/100. *np.sum(vals)) 
    return "{:.1f}% \n({:d} g)".format(pct, absolute)

wedges, texts, autotexts = ax.pie(data, autopct = lambda pct: func(pct, data), textprops = dict(color = 'w'))
ax.legend(wedges, ingredients, title = 'ingredients', loc = 'center left')
plt.show()

# %%
fig, ax = plt.subplots (dpi = 150) # --> Changed
recipe = ["375 g Flour", "75 g Suger", "250 g Butter", "300 g Berries"]

data = [float(x.split(' ')[0]) for x in recipe]
ingredients = [x.split(' ')[-1] for x in recipe]

def func(pct, vals):
    absolute = int(pct/100. *np.sum(vals)) 
    return "{:.1f}% \n({:d} g)".format(pct, absolute)

wedges, texts, autotexts = ax.pie(data, autopct = lambda pct: func(pct, data), textprops = dict(color = 'w'))
ax.legend(wedges, ingredients, title = 'ingredients', loc = 'center left', bbox_to_anchor = (1,0,1,1))
plt.show()

# %% [markdown]
# ## Bar Chart on Polar Axis

# %%
np.random.seed(0)
N = 20

theta = np.linspace(0.0,2*np.pi, N, endpoint = False) 
radii = 10*np.random.rand(N)
width = np.pi/4*np.random.rand(N)
colors = plt.cm.plasma(radii/10)

plt.figure(dpi = 100)
ax = plt.subplot((111), projection = 'polar') 
ax.bar(theta, radii, width = width, bottom = 0, color = colors, alpha = 0.7)
plt.show()

# %%
np.random.seed(0)
N = 30

theta = np.linspace(0.0,2*np.pi, N, endpoint = False) 
radii = 10*np.random.rand(N)
width = np.pi/4*np.random.rand(N)
colors = plt.cm.plasma(radii/10)

plt.figure(dpi = 100)
ax = plt.subplot((111), projection = 'polar') 
ax.bar(theta, radii, width = width, bottom = 0, color = colors, alpha = 0.7)
plt.show()

# %% [markdown]
# ## Line Plot on Polar Axis

# %%
r = np.arange(0,2, 0.01)
theta = 2*np.pi*r

plt.figure(dpi = 100)
ax = plt.subplot(111, projection = 'polar')
ax.plot(theta, r)
ax.set_rmax= (2)
plt.show()

# %%
r = np.arange(0,2, 0.01)
theta = 2*np.pi*r

plt.figure(dpi = 100)
ax = plt.subplot(111, projection = 'polar')
ax.plot(theta, r)
ax.set_rmax= (2)
ax.set_rticks([0, 0.5, 1, 1.5]) # --> Changes the values 
ax.set_rlabel_position(-30) # --> changes position of labels
ax.grid(False) # --> This removes grid
plt.show()

# %% [markdown]
# ## Scatter Plot on Polar Axis

# %%
np.random.seed(0)
N = 150

r = 2*np.random.rand(N)
theta = 2*np.pi*np.random.rand(N)
area = 50*2*np.pi*r**2
colors = theta

fig = plt.figure(dpi = 100)
ax = fig.add_subplot(111, projection = 'polar') 
c = ax.scatter(theta, r,c = colors, s = area, cmap = 'hsv', alpha = 0.8)
plt.show()

# %%
np.random.seed(0)
N = 150

r = 2*np.random.rand(N)
theta = 2*np.pi*np.random.rand(N)
area = 50*2*np.pi*r**2
colors = theta

fig = plt.figure(dpi = 100)
ax = fig.add_subplot(111, projection = 'polar') 
ax.set_rticks([0, 0.5, 1, 1.5]) 
c = ax.scatter(theta, r,c = colors, s = area, cmap = 'hsv', alpha = 0.8)
plt.show()

# %% [markdown]
# ## Integral as the Area Under the Curve

# %%
from matplotlib.patches import Polygon

# %%
def func(x):
    return (x-3) * (x-5) * (x-7) + 85

a, b = 2,9
x = np.linspace(0,10)
y = func(x)

fig, ax = plt.subplots(dpi = 100)
ax.plot(x, y, 'r', linewidth = 2)
ax.set_ylim(bottom = 0)

ix = np.linspace(a,b)
iy = func(ix)
verts = [(a,0), *zip(ix, iy), (b,0)]
poly = Polygon(verts, facecolor = '0.9', edgecolor = '0.5')
ax.add_patch(poly)

ax.text(0.5*(a + b), 30, r"$\int_a^b f(x)dx$", horizontalalignment = 'center', fontsize = 20)

fig.text(0.9, 0.05, 'x') 
fig.text(0.1, 0.9, 'y')

ax.spines['right'].set_visible(False) 
ax.spines['top'].set_visible (False) 
ax.xaxis.set_ticks_position('bottom')

# %%
def func(x):
    return (x-3) * (x-5) * (x-7) + 85

a, b = 2,9
x = np.linspace(0,10)
y = func(x)

fig, ax = plt.subplots(dpi = 100)
ax.plot(x, y, 'r', linewidth = 2)
ax.set_ylim(bottom = 0)

ix = np.linspace(a,b)
iy = func(ix)
verts = [(a,0), *zip(ix, iy), (b,0)]
poly = Polygon(verts, facecolor = '0.9', edgecolor = '0.5')
ax.add_patch(poly)

ax.text(0.5*(a + b), 30, r"$\int_a^b f(x)dx$", horizontalalignment = 'center', fontsize = 20)

fig.text(0.9, 0.05, 'x') 
fig.text(0.1, 0.9, 'y')

ax.spines['right'].set_visible(False) 
ax.spines['top'].set_visible (False) 
ax.xaxis.set_ticks_position('bottom')

ax.set_xticks((a,b))
ax.set_xticklabels(('a', 'b'))
plt.show()
